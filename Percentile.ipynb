# %%
import pandas as pd

# %%
dataset = pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %%
from univariate import Univariate

# %%
Quan,Qual=Univariate.QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive = pd.DataFrame(index=["Mean","Median","Mode","Q1:25 %","Q2:50 %","Q3:75 %","99 %","Q4:100 %"], columns=Quan)

# %%
descriptive
# Out:
#          sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q1:25 %    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q2:50 %    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q3:75 %    NaN   NaN   NaN      NaN     NaN   NaN    NaN
# 99 %       NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Q4:100 %   NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
import warnings
warnings.filterwarnings("ignore")

# %%
import numpy as np

# %%
np.percentile(dataset["ssc_p"],100)
# Out:
# np.float64(89.4)

# %%
for col in Quan:
    descriptive[col]["Mean"]=dataset[col].mean()
    descriptive[col]["Median"]=dataset[col].median()
    descriptive[col]["Mode"]=dataset[col].mode()[0]
#    descriptive[col]["Q1:25 %"] = np.percentile(dataset[col],25)
    descriptive[col]["Q1:25 %"] = dataset.describe()[col]["25%"]
#    descriptive[col]["Q2:50 %"] = np.percentile(dataset[col],50)
    descriptive[col]["Q2:50 %"] = dataset.describe()[col]["50%"]    
#    descriptive[col]["Q3:75 %"] = np.percentile(dataset[col],75)
    descriptive[col]["Q3:75 %"] = dataset.describe()[col]["75%"]    
#    descriptive[col]["Q4:100 %"] = np.percentile(dataset[col],100)
    descriptive[col]["99 %"] = np.percentile(dataset[col],99)
    descriptive[col]["Q4:100 %"] = dataset.describe()[col]["max"]

# %%
descriptive
# Out:
#            sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean       108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median     108.0       67.0       65.0       66.0       71.0       62.0
# Mode           1       62.0       63.0       65.0       60.0       56.7
# Q1:25 %     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50 %    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75 %    161.5       75.7       73.0       72.0       83.5     66.255
# 99 %      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100 %   215.0       89.4       97.7       91.0       98.0      77.89
#
#                  salary
# Mean      288655.405405
# Median         265000.0
# Mode           300000.0
# Q1:25 %        240000.0
# Q2:50 %        265000.0
# Q3:75 %        300000.0
# 99 %                NaN
# Q4:100 %       940000.0

# %% [markdown]
# # Percentile Summary
# For column: ssc_p
# Q1:25% ssc_p: 60.6. In the data population 25% (1st quadrant) percentile data would be under 60.6.
# Q2:50% ssc_p: 67.0. In the data population 50% (2nd quadrant) percentile data would be under 67.0. The value increaes from 1st Quadarand is 6.4.
# Q3:75% ssc_p: 75.7. In the data population 75% (3rd quadrant) percentile data would be under 75.7. The value increaes from 2nd Quadarand is 8.7.
# 99 % : 87.0. In the data population 99%  percentile data would be under 87.0. The value increaes from 3rd Quadarand is 11.3.
# Q4:100% ssc_p: 89.4. In the data population 100% (max) percentile data would be under 89.4. The value increaes from 3rd Quadarand is 13.7.
#
# For column: hsc_p
# Q1:25% hsc_p: 60.9. In the data population 25% (1st quadrant) percentile data would be under 60.9.
# Q2:50% hsc_p: 65.0. In the data population 50% (2nd quadrant) percentile data would be under 65.0. The value increaes from 1st Quadarand is 4.1.
# Q3:75% hsc_p: 73.0. In the data population 75% (3rd quadrant) percentile data would be under 73.0. The value increaes from 2nd Quadarand is 8.
# 99 % : 91.86. In the data population 99%  percentile data would be under 91.86. The value increaes from 3rd Quadarand is 18.86.
# Q4:100% ssc_p: 97.7. In the data population 100% (max) percentile data would be under 97.7. The value increaes from 3rd Quadarand is 24.7.
#
# For column: degree_p
# Q1:25% degree_p: 61.0 In the data population 25% (1st quadrant) percentile data would be under 61.
# Q2:50% degree_p: 66.0. In the data population 50% (2nd quadrant) percentile data would be under 66.0. The value increaes from 1st Quadarand is 5.
# Q3:75% degree_p: 72.0. In the data population 75% (3rd quadrant) percentile data would be under 72.0. The value increaes from 2nd Quadarand is 6.
# 99 % : 83.86. In the data population 99%  percentile data would be under 83.86. The value increaes from 3rd Quadarand is 11.86.
# Q4:100% ssc_p: 91 In the data population 100% (max) percentile data would be under 91. The value increaes from 3rd Quadarand is 19.
#
# For column: etest_p
# Q1:25% etest_p: 60.0. In the data population 25% (1st quadrant) percentile data would be under 60.0.
# Q2:50% etest_p: 71.0. In the data population 50% (2nd quadrant) percentile data would be under 71.0. The value increaes from 1st Quadarand is 11.
# Q3:75% etest_p: 83.5. In the data population 75% (3rd quadrant) percentile data would be under 83.5. The value increaes from 2nd Quad is 12.5.
# 99 % : 97. In the data population 99%  percentile data would be under 97. The value increaes from 3rd Quadarand is 28.
# Q4:100% ssc_p: 98. In the data population 100% (max) percentile data would be under 98. The value increaes from 3rd Quadarand is 27.
#
# For column: mba_p
# Q1:25% mba_p: 57.9. In the data population 25% (1st quadrant) percentile data would be under 57.9.
# Q2:50% mba_p: 62.0. In the data population 50% (2nd quadrant) percentile data would be under 62.0. The value increaes from 1st Quadarand is 4.1.
# Q3:75% mba_p: 66.255. In the data population 75% (3rd quadrant) percentile data would be under 66.255. The value increaes from 2nd Quad is 4.255.
# 99 % :76.1. In the data population 99%  percentile data would be under 76.1. The value increaes from 3rd Quadarand is 9.9.
# Q4:100% ssc_p: 77.89. In the data population 100% (max) percentile data would be under 77.89. The value increaes from 3rd Quadarand is 11.7.

# %%
descriptive = pd.DataFrame(index=["Mean","Median","Mode","Q1:25 %","Q2:50 %","Q3:75 %","99 %","Q4:100 %","IQR","1.5Rule","Lesser","Greater","Min","Max"], columns=Quan)
for col in Quan:
    descriptive[col]["Mean"]=dataset[col].mean()
    descriptive[col]["Median"]=dataset[col].median()
    descriptive[col]["Mode"]=dataset[col].mode()[0]
    descriptive[col]["Q1:25 %"] = dataset.describe()[col]["25%"]
    descriptive[col]["Q2:50 %"] = dataset.describe()[col]["50%"]    
    descriptive[col]["Q3:75 %"] = dataset.describe()[col]["75%"]    
    descriptive[col]["99 %"] = np.percentile(dataset[col],99)
    descriptive[col]["Q4:100 %"] = dataset.describe()[col]["max"]
    descriptive[col]["IQR"] = dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"]
    descriptive[col]["1.5Rule"] =1.5*(dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"])
    descriptive[col]["Lesser"] =dataset.describe()[col]["25%"] - (1.5*(dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"]))
    descriptive[col]["Greater"] =dataset.describe()[col]["75%"] + (1.5*(dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"]))
    descriptive[col]["Min"] = dataset[col].min()
    descriptive[col]["Max"] = dataset[col].max()

# %%
descriptive
# Out:
#            sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean       108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median     108.0       67.0       65.0       66.0       71.0       62.0
# Mode           1       62.0       63.0       65.0       60.0       56.7
# Q1:25 %     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50 %    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75 %    161.5       75.7       73.0       72.0       83.5     66.255
# 99 %      212.86       87.0      91.86      83.86       97.0    76.1142
# Q4:100 %   215.0       89.4       97.7       91.0       98.0      77.89
# IQR        107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule    160.5      22.65      18.15       16.5      35.25     12.465
# Lesser    -106.0      37.95      42.75       44.5      24.75      45.48
# Greater    322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
if descriptive["hsc_p"]["Lesser"] < descriptive["hsc_p"]["Min"] :
    print("Not Outlier")
else:
    print("Outlier")
# Out:
# Outlier

# %%
lesser=[]
greater=[]
for cols in Quan:
    if descriptive[cols]["Min"]<descriptive[cols]["Lesser"]:
        lesser.append(cols)
    if descriptive[cols]["Max"]>descriptive[cols]["Greater"]:
        greater.append(cols)

print(lesser)
print(greater)
# Out:
# ['hsc_p']
# ['hsc_p', 'degree_p', 'salary']

# %%
for columnName in lesser:
    dataset[columnName][dataset[columnName]<descriptive[columnName]["Lesser"]] = descriptive[columnName]["Lesser"]

for columnName in greater:
    dataset[columnName][dataset[columnName]>descriptive[columnName]["Greater"]] = descriptive[columnName]["Greater"]

# %%
descriptive = pd.DataFrame(index=["Mean","Median","Mode","Q1:25 %","Q2:50 %","Q3:75 %","99 %","Q4:100 %","IQR","1.5Rule","Lesser","Greater","Min","Max"], columns=Quan)
for col in Quan:
    descriptive[col]["Mean"]=dataset[col].mean()
    descriptive[col]["Median"]=dataset[col].median()
    descriptive[col]["Mode"]=dataset[col].mode()[0]
    descriptive[col]["Q1:25 %"] = dataset.describe()[col]["25%"]
    descriptive[col]["Q2:50 %"] = dataset.describe()[col]["50%"]    
    descriptive[col]["Q3:75 %"] = dataset.describe()[col]["75%"]    
    descriptive[col]["99 %"] = np.percentile(dataset[col],99)
    descriptive[col]["Q4:100 %"] = dataset.describe()[col]["max"]
    descriptive[col]["IQR"] = dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"]
    descriptive[col]["1.5Rule"] =1.5*(dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"])
    descriptive[col]["Lesser"] =dataset.describe()[col]["25%"] - (1.5*(dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"]))
    descriptive[col]["Greater"] =dataset.describe()[col]["75%"] + (1.5*(dataset.describe()[col]["75%"] -  dataset.describe()[col]["25%"]))
    descriptive[col]["Min"] = dataset[col].min()
    descriptive[col]["Max"] = dataset[col].max()

# %%
descriptive
# Out:
#            sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean       108.0  67.303395  66.334744  66.358558  72.100558  62.278186
# Median     108.0       67.0       65.0       66.0       71.0       62.0
# Mode           1       62.0       63.0       65.0       60.0       56.7
# Q1:25 %     54.5       60.6       60.9       61.0       60.0     57.945
# Q2:50 %    108.0       67.0       65.0       66.0       71.0       62.0
# Q3:75 %    161.5       75.7       73.0       72.0       83.5     66.255
# 99 %      212.86       87.0     91.129      83.86       97.0    76.1142
# Q4:100 %   215.0       89.4      91.15       88.5       98.0      77.89
# IQR        107.0       15.1       12.1       11.0       23.5       8.31
# 1.5Rule    160.5      22.65      18.15       16.5      35.25     12.465
# Lesser    -106.0      37.95      42.75       44.5      24.75      45.48
# Greater    322.0      98.35      91.15       88.5     118.75      78.72
# ...

# %%
lesser=[]
greater=[]
for cols in Quan:
    if descriptive[cols]["Min"]<descriptive[cols]["Lesser"]:
        lesser.append(cols)
    if descriptive[cols]["Max"]>descriptive[cols]["Greater"]:
        greater.append(cols)

print(lesser)
print(greater)
# Out:
# []
# []
