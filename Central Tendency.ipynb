# %%
import pandas as pd

# %%
dataset = pd.read_csv("Placement.csv")

# %%
dataset
# Out:
#      sl_no gender  ssc_p    ssc_b  hsc_p    hsc_b     hsc_s  degree_p  \
# 0        1      M  67.00   Others  91.00   Others  Commerce     58.00
# 1        2      M  79.33  Central  78.33   Others   Science     77.48
# 2        3      M  65.00  Central  68.00  Central      Arts     64.00
# 3        4      M  56.00  Central  52.00  Central   Science     52.00
# 4        5      M  85.80  Central  73.60  Central  Commerce     73.30
# ..     ...    ...    ...      ...    ...      ...       ...       ...
# 210    211      M  80.60   Others  82.00   Others  Commerce     77.60
# 211    212      M  58.00   Others  60.00   Others   Science     72.00
# 212    213      M  67.00   Others  67.00   Others  Commerce     73.00
# 213    214      F  74.00   Others  66.00   Others  Commerce     58.00
# 214    215      M  62.00  Central  58.00   Others   Science     53.00
#
#       degree_t workex  etest_p specialisation  mba_p      status    salary
# ...

# %% [markdown]
# # Central Tendency

# %%
dataset["ssc_p"].mean()
# Out:
# np.float64(67.30339534883721)

# %%
dataset["ssc_p"].median()
# Out:
# np.float64(67.0)

# %%
dataset["ssc_p"].mode()
# Out:
# 0    62.0
# Name: ssc_p, dtype: float64

# %%
dataset["ssc_p"].mode()[0]
# Out:
# np.float64(62.0)

# %%
dataset.describe()
# Out:
#             sl_no       ssc_p       hsc_p    degree_p     etest_p       mba_p  \
# count  215.000000  215.000000  215.000000  215.000000  215.000000  215.000000
# mean   108.000000   67.303395   66.333163   66.370186   72.100558   62.278186
# std     62.209324   10.827205   10.897509    7.358743   13.275956    5.833385
# min      1.000000   40.890000   37.000000   50.000000   50.000000   51.210000
# 25%     54.500000   60.600000   60.900000   61.000000   60.000000   57.945000
# 50%    108.000000   67.000000   65.000000   66.000000   71.000000   62.000000
# 75%    161.500000   75.700000   73.000000   72.000000   83.500000   66.255000
# max    215.000000   89.400000   97.700000   91.000000   98.000000   77.890000
#
#               salary
# count     148.000000
# mean   288655.405405
# std     93457.452420
# min    200000.000000
# 25%    240000.000000
# 50%    265000.000000
# 75%    300000.000000
# max    940000.000000

# %%
descriptive = pd.DataFrame()

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
descriptive = pd.DataFrame(index=["Mean","Median","Mode"])

# %%
descriptive
# Out:
# Empty DataFrame
# Columns: []
# Index: [Mean, Median, Mode]

# %%
from univariate import Univariate

# %%
Quan,Qual=Univariate.QuanQual(dataset)

# %%
Quan
# Out:
# ['sl_no', 'ssc_p', 'hsc_p', 'degree_p', 'etest_p', 'mba_p', 'salary']

# %%
descriptive = pd.DataFrame(index=["Mean","Median","Mode"], columns=Quan)

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
descriptive["hsc_p"]["Median"]=0
# Out:
# C:\Users\pripo\AppData\Local\Temp\ipykernel_18752\2333899791.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive["hsc_p"]["Median"]=0

# %%
descriptive
# Out:
#        sl_no ssc_p hsc_p degree_p etest_p mba_p salary
# Mean     NaN   NaN   NaN      NaN     NaN   NaN    NaN
# Median   NaN   NaN     0      NaN     NaN   NaN    NaN
# Mode     NaN   NaN   NaN      NaN     NaN   NaN    NaN

# %%
for col in Quan:
    descriptive[col]["Mean"]=dataset[col].mean()
    descriptive[col]["Median"]=dataset[col].median()
    descriptive[col]["Mode"]=dataset[col].mode()[0]
# Out:
# C:\Users\pripo\AppData\Local\Temp\ipykernel_18752\330314331.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   descriptive[col]["Mean"]=dataset[col].mean()
# ...

# %%
descriptive
# Out:
#         sl_no      ssc_p      hsc_p   degree_p    etest_p      mba_p  \
# Mean    108.0  67.303395  66.333163  66.370186  72.100558  62.278186
# Median  108.0       67.0       65.0       66.0       71.0       62.0
# Mode        1       62.0       63.0       65.0       60.0       56.7
#
#                salary
# Mean    288655.405405
# Median       265000.0
# Mode         300000.0

# %% [markdown]
# # Summary ssc_p
# 1. Mean value ssc_p: Out of Placement dataset the mean value of ssc_p mark is 67.3
# 2. Median value ssc_p: Out of Placement dataset the median value of ssc_p mark is 67.
# 3. Mode value ssc_p: Out of Placement dataset the mode value of ssc_p mark is 62. Most of students got 62
#
# # Summary hsc_p
# 1. Mean value hsc_p: Out of Placement dataset the mean value of hsc_p mark is 66.3
# 2. Median value hsc_p: Out of Placement dataset the median value of hsc_p mark is 65.
# 3. Mode value hsc_p: Out of Placement dataset the mode value of hsc_p mark is 63. Most of students got 63
#
# # Summary degree_p
# 1. Mean value degree_p: Out of Placement dataset the mean value of degree_p mark is 66.3
# 2. Median value degree_p: Out of Placement dataset the median value of degeree_p mark is 66.
# 3. Mode value degree_p: Out of Placement dataset the mode value of degree_p mark is 65. Most of students got 65
#
# # Summary etest_p
# 1. Mean value etest_p: Out of Placement dataset the mean value of etest_p mark is 72.1
# 2. Median value etest_p: Out of Placement dataset the median value of etest_p mark is 71.
# 3. Mode value etest_p: Out of Placement dataset the mode value of etest_p mark is 60. Most of students got 60
#
# # Summary mba_p
# 1. Mean value mba_p: Out of Placement dataset the mean value of mba_p mark is 62.2
# 2. Median value mba_p: Out of Placement dataset the median value of mba_p mark is 62.
# 3. Mode value mba_p: Out of Placement dataset the mode value of mba_p mark is 56.7. Most of students got 56.7
#
# # Summary salary
# 1. Mean value salary: Out of Placement dataset the mean value of salary mark is 288655.4
# 2. Median value salary: Out of Placement dataset the median value of salary mark is 265000.0.
# 3. Mode value salary: Out of Placement dataset the mode value of salary mark is 300000.0. Most of students got 300000.0
